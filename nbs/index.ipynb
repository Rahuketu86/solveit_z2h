# %%
#| hide
from solveit_z2h.core import *

# %% [markdown]
# # solveit_z2h
#
# > Zero to hero course done using solveit

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install solveit_z2h in Development mode

# %% [markdown]
# ```sh
# # make sure solveit_z2h package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to solveit_z2h
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/Rahuketu86/solveit_z2h.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c Rahuketu86 solveit_z2h
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install solveit_z2h
# ```
#
#
# [repo]: https://github.com/Rahuketu86/solveit_z2h
# [docs]: https://Rahuketu86.github.io/solveit_z2h/
# [pypi]: https://pypi.org/project/solveit_z2h/
# [conda]: https://anaconda.org/Rahuketu86/solveit_z2h

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/Rahuketu86/solveit_z2h
# [docs]: https://Rahuketu86.github.io/solveit_z2h/
# [pypi]: https://pypi.org/project/solveit_z2h/
# [conda]: https://anaconda.org/Rahuketu86/solveit_z2h

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
